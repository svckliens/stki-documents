# %% [markdown]
# ## Text summarization (Senetnce Ranking)
#
# #### STEP 1 : Data cleaning ( removing non letter characters, turning to lower case letters )
# #### STEP 2 : Building Sentence Similarity Matrix
# #### STEP 3 : Sentence Ranking
# #### STEP 4 : Summary Generation

# %% [markdown]
# ## Initial Phase
# ### Importing Libraries and Reading Data

# %%
import os
BASE_DIR = r"E:\STKI\Minggu-11"
os.chdir(BASE_DIR)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\asus\appdata\roaming\python\python311\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\asus\appdata\roaming\python\python311\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\asus\appdata\roaming\python\python311\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\asus\appdata\roaming\python\python311\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2025.11.3-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in e:\stki\minggu-11\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached regex-2025.11.3-cp311-cp311-win_amd64.whl (277 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    ---------------------------------------- 5/5 [nltk]
#
# Successfully installed click-8.3.1 joblib-1.5.3 nltk-3.9.2 regex-2025.11.3 tqdm-4.67.1

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
print(stopwords.words('english')[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
import sys
# !{sys.executable} -m pip install numpy pandas nltk networkx
# Out:
# Collecting numpy
#   Using cached numpy-2.3.5-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting pandas
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: nltk in e:\stki\minggu-11\.venv\lib\site-packages (3.9.2)
# Collecting networkx
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\stki\minggu-11\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: click in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in e:\stki\minggu-11\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in e:\stki\minggu-11\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Downloading numpy-2.3.5-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.1 MB 840.2 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/13.1 MB 1.1 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/13.1 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.6/13.1 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/13.1 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/13.1 MB 1.3 MB/s eta 0:00:09
#    ------- -------------------------------- 2.4/13.1 MB 1.3 MB/s eta 0:00:09
#    -------- ------------------------------- 2.6/13.1 MB 1.3 MB/s eta 0:00:09
#    -------- ------------------------------- 2.9/13.1 MB 1.3 MB/s eta 0:00:08
#    --------- ------------------------------ 3.1/13.1 MB 1.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.4/13.1 MB 1.3 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/13.1 MB 1.4 MB/s eta 0:00:07
#    ------------ --------------------------- 4.2/13.1 MB 1.4 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.1 MB 1.4 MB/s eta 0:00:07
#    -------------- ------------------------- 4.7/13.1 MB 1.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 5.2/13.1 MB 1.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.5/13.1 MB 1.4 MB/s eta 0:00:06
#    ------------------ --------------------- 6.0/13.1 MB 1.5 MB/s eta 0:00:05
#    ------------------- -------------------- 6.3/13.1 MB 1.5 MB/s eta 0:00:05
#    ------------------- -------------------- 6.3/13.1 MB 1.5 MB/s eta 0:00:05
#    -------------------- ------------------- 6.8/13.1 MB 1.5 MB/s eta 0:00:05
#    --------------------- ------------------ 7.1/13.1 MB 1.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.3/13.1 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/13.1 MB 1.5 MB/s eta 0:00:04
#    ------------------------ --------------- 7.9/13.1 MB 1.4 MB/s eta 0:00:04
#    ------------------------ --------------- 8.1/13.1 MB 1.4 MB/s eta 0:00:04
#    ------------------------- -------------- 8.4/13.1 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 8.7/13.1 MB 1.4 MB/s eta 0:00:04
#    --------------------------- ------------ 8.9/13.1 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 8.9/13.1 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.2/13.1 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.2/13.1 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.4/13.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.4/13.1 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.1 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.1 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 10.0/13.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 10.0/13.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 10.0/13.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 10.2/13.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 10.2/13.1 MB 1.2 MB/s eta 0:00:03
#    -------------------------------- ------- 10.5/13.1 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.5/13.1 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.7/13.1 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.7/13.1 MB 1.1 MB/s eta 0:00:03
#    --------------------------------- ------ 11.0/13.1 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 11.0/13.1 MB 1.1 MB/s eta 0:00:02
#    --------------------------------- ------ 11.0/13.1 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/13.1 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.3/13.1 MB 1.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/13.1 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.5/13.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 11.8/13.1 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 12.1/13.1 MB 990.8 kB/s eta 0:00:02
#    ------------------------------------ --- 12.1/13.1 MB 990.8 kB/s eta 0:00:02
#    ------------------------------------ --- 12.1/13.1 MB 990.8 kB/s eta 0:00:02
#    ------------------------------------- -- 12.3/13.1 MB 964.7 kB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.1 MB 964.7 kB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.1 MB 964.7 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 948.9 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 472.0 kB/s eta 0:00:01
#    ---------------------------------------  12.8/13.1 MB 472.0 kB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 473.6 kB/s  0:00:28
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 266.4 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.5/2.1 MB 266.4 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.5/2.1 MB 266.4 kB/s eta 0:00:06
#    --------------- ------------------------ 0.8/2.1 MB 360.8 kB/s eta 0:00:04
#    --------------- ------------------------ 0.8/2.1 MB 360.8 kB/s eta 0:00:04
#    -------------------- ------------------- 1.0/2.1 MB 423.0 kB/s eta 0:00:03
#    -------------------- ------------------- 1.0/2.1 MB 423.0 kB/s eta 0:00:03
#    ------------------------- -------------- 1.3/2.1 MB 441.5 kB/s eta 0:00:02
#    ------------------------- -------------- 1.3/2.1 MB 441.5 kB/s eta 0:00:02
#    ------------------------- -------------- 1.3/2.1 MB 441.5 kB/s eta 0:00:02
#    ------------------------------ --------- 1.6/2.1 MB 441.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.6/2.1 MB 441.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 1.8/2.1 MB 477.2 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 477.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 479.8 kB/s  0:00:04
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, networkx, pandas
#
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    ---------------------------------------- 0/5 [pytz]
#    -------- ------------------------------- 1/5 [tzdata]
#    -------- ------------------------------- 1/5 [tzdata]
#    -------- ------------------------------- 1/5 [tzdata]
#    -------- ------------------------------- 1/5 [tzdata]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ---------------- ----------------------- 2/5 [numpy]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    ------------------------ --------------- 3/5 [networkx]
#    -------------------------------- ------- 4/5 [pandas]
#    -------------------------------- ------- 4/5 [pandas]
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'e:\\STKI\\Minggu-11\\.venv\\Lib\\site-packages\\pandas\\core\\arrays\\sparse\\array.py'
# Check the permissions.
# Requirement already satisfied: numpy in e:\stki\minggu-11\.venv\lib\site-packages (2.3.5)
# Collecting pandas
#   Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: nltk in e:\stki\minggu-11\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: networkx in e:\stki\minggu-11\.venv\lib\site-packages (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\stki\minggu-11\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\stki\minggu-11\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\stki\minggu-11\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: click in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in e:\stki\minggu-11\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in e:\stki\minggu-11\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in e:\stki\minggu-11\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.3.3

# %%
### importing the necessary libraries

from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import numpy as np
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
import networkx as nx
from nltk.tokenize import  sent_tokenize

# %%
import os
os.getcwd()
# Out:
# 'e:\\STKI\\Minggu-11\\textSummarization\\.ipynb_checkpoints'

# %%
df = pd.read_csv("Data/tennis_articles_v4.csv")
df.head()
# Out:
#    article_id                                       article_text  \
# 0           1  Maria Sharapova has basically no friends as te...
# 1           2  BASEL, Switzerland (AP), Roger Federer advance...
# 2           3  Roger Federer has revealed that organisers of ...
# 3           4  Kei Nishikori will try to end his long losing ...
# 4           5  Federer, 37, first broke through on tour over ...
#
#                                               source
# 0  https://www.tennisworldusa.org/tennis/news/Mar...
# 1  http://www.tennis.com/pro-game/2018/10/copil-s...
# 2  https://scroll.in/field/899938/tennis-roger-fe...
# 3  http://www.tennis.com/pro-game/2018/10/nishiko...
# 4  https://www.express.co.uk/sport/tennis/1036101...

# %%
## working with re ( regular expression in python)

import re
s = 'he&&&s'
s = re.sub("[^a-zA-Z]"," ",s)

# %% [markdown]
# ## STEP 1 : Data Cleaning
# ### Cleaning sentences, by removing Non Alphabet Characters and converting to Lower Case Letters

# %%
from nltk.tokenize import sent_tokenize

# %%
### cleaning sentences, by removing non alphabet characters and converting to lower case letters

dict = {}
s = ""
for a in df['article_text']:
      s += a
# print s
s = s.lower()
# print s

sentences = sent_tokenize(s)
# print sentences

final = []

for s in sentences:
      temp = re.sub("[^a-zA-Z]"," ",s)
      temp = temp.lower()
      final.append(temp)
      dict[temp] = s
# printfinal

# %% [markdown]
# ## STEP 2 : Building Senetnce Similarity Matrix
# ### Similarity is found using Cosine Similarity between vector representation of sentences

# %%
### define method for calculating similarity

def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)




def build_similarity_matrix(sentences, stop_words):
    # Create an empty similarity matrix
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
 
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1 == idx2: #ignore if both are same sentences
                continue 
            similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)
    return similarity_matrix

# %% [markdown]
# ## STEP 3 : Sentence Ranking
# ### Sentences are ranked using PageRank Algorithm on the Graph generated from the Sentence Similarity Matrix

# %%
import numpy as np
import pandas as pd
import networkx as nx
import nltk
import re

from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
from nltk.tokenize import sent_tokenize

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import sys
# !{sys.executable} -m pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in e:\stki\minggu-11\.venv\lib\site-packages (from scipy) (2.3.5)
# Using cached scipy-1.16.3-cp311-cp311-win_amd64.whl (38.7 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.3

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.16.3

# %%
# generating the final summary : graph is generated using networkx library 
# and cosine similarity matrix containing adjacency list;
# after that sentences are scored using pagerank and sorted and stored in ranked_sentences

# Step 2 - Generate Similarity Matrix across sentences
stop_words = stopwords.words('english')
sentence_similarity_matrix = build_similarity_matrix(final, stop_words)

# Step 3 - Rank sentences in similarity matrix
sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_matrix)
scores = nx.pagerank(sentence_similarity_graph)

# Step 4 - Sort the rank and pick top sentences
ranked_sentence = sorted(
    ((scores[i], s) for i, s in enumerate(final)),
    reverse=True
)

# Step 5 - Output the summarized text
summarize_text = []
for i in range(5):   # ambil 5 kalimat teratas
    summarize_text.append(" ".join(ranked_sentence[i][1]))

print("Summarized Text:\n")
print(". ".join(summarize_text))
# Out:
# Summarized Text:
#
# s p e a k i n g   a t   t h e   s w i s s   i n d o o r s   t o u r n a m e n t   w h e r e   h e   w i l l   p l a y   i n   s u n d a y s   f i n a l   a g a i n s t   r o m a n i a n   q u a l i f i e r   m a r i u s   c o p i l     t h e   w o r l d   n u m b e r   t h r e e   s a i d   t h a t   g i v e n   t h e   i m p o s s i b l y   s h o r t   t i m e   f r a m e   t o   m a