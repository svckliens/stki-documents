# %% [markdown]
# ## Klasifikasi Text Mining menggunakan Naive Bayes

# %% [markdown]
# # load drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.append('/content/drive/My Drive/Colab Notebooks/AMS2023')

# %% [markdown]
# # install library ekphrasis

# %%
# !pip install ekphrasis

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

# %% [markdown]
# # load library

# %%
import re
import string 
import pandas as pd
from copy import deepcopy

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %% [markdown]
# # load dataset

# %%
import pandas as pd

df = pd.read_csv(r"e:\STKI\Minggu-8\Dataset_Sentimen_Emosi.csv")
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0     -2
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0     -2

# %%
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0     -2
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0     -2

# %% [markdown]
# karena kita hanya ingin fokus di Sentimen analysis, maka kita hanya pakai `Sentimen` sebagai target class nya **class**

# %%
df = df.drop(['Emosi'], axis=1)

# %%
df.head()
# Out:
#                                                Tweet  Sentimen
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## setting fungsi

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %% [markdown]
# ## running preprocessing
# logika main disini

# %%
import os

# Lihat folder kerja saat ini
print("Current working directory:", os.getcwd())

# List semua file dan folder di working directory
files = os.listdir()
print(files)
# Out:
# Current working directory: e:\STKI\Minggu-8\.ipynb_checkpoints
# ['01-TFIDF-checkpoint.ipynb', '02-Klasifikasi Text Mining Naive Bayes-checkpoint.ipynb', '02_-Klasifikasi Text Mining Naive Bayes-checkpoint.ipynb', 'stats.zip']

# %%
import pandas as pd

dataset = pd.read_csv(r"e:\STKI\Minggu-8\Dataset_Sentimen_Emosi.csv", sep=';', on_bad_lines='skip')
print(dataset.head())
# Out:
#                                 Tweet,Sentimen,Emosi
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...
# 4       Covid belum nyampe prigen mbak hmm hoax,0,-2

# %%
print(dataset.columns)
# Out:
# Index(['Tweet,Sentimen,Emosi'], dtype='object')

# %%
dataset = pd.read_csv(r"e:\STKI\Minggu-8\Dataset_Sentimen_Emosi.csv", sep=',')

# %%
import re
import string

def clean_text(text):
    text = text.lower()
    text = re.sub(r'rt\s+', '', text)
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

dataset['ProcessedText'] = dataset['Tweet'].astype(str).apply(clean_text)

# %%
import re
import string

final_string = []

for text in df['Tweet'].astype(str).values:  # pastikan kolom 'Tweet' benar
    proc = text.lower()
    proc = re.sub(r'rt\s+', '', proc)
    proc = re.sub(r'http\S+|www\S+', '', proc)
    proc = re.sub(r'@\w+', '', proc)
    proc = re.sub(r'#\w+', '', proc)
    proc = re.sub(r'\d+', '', proc)
    proc = re.sub(r'[{}]'.format(re.escape(string.punctuation)), '', proc)
    proc = re.sub(r'\s+', ' ', proc).strip()
    final_string.append(proc)

# Sekarang panjang final_string harus sama dengan jumlah baris df
print(len(final_string), len(df))  # harus sama
# Out:
# 905 905

# %% [markdown]
# masukkan hasil preprocessing ke kolom `step01`

# %%
df["step01"] = final_string

# %%
df.head(1)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
#
#                                        ProcessedText  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
#
#                                               step01
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...

# %% [markdown]
# cek jumlah dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tweet          905 non-null    object
#  1   Sentimen       904 non-null    float64
#  2   ProcessedText  905 non-null    object
#  3   step01         905 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 28.4+ KB

# %% [markdown]
# ## hapus record yang kosong

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 903 entries, 0 to 904
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tweet          903 non-null    object
#  1   Sentimen       903 non-null    float64
#  2   ProcessedText  903 non-null    object
#  3   step01         903 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 35.3+ KB

# %% [markdown]
# ## normalisasi kata slang

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
# 5  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 6  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 7  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 8  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 9  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
#
#                                        ProcessedText  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
# 1  cegah mata rantai covidmari kita dirumah saja ...
# 2  aku mohon yaallah semoga wabah covid menghilan...
# 3  pemprov papua naikkan status jadi tanggap daru...
# ...

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

normalized_word = pd.read_excel(r"E:\STKI\Minggu-8\kamus perbaikan kata.xlsx")

# %%
normalized_word_dict = {}
for index, row in normalized_word.iterrows():
    normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

df_new['tokens_perbaikan'] = df_new['tokens'].apply(normalized_term)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10468\3235176671.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new.head()
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
#
#                                        ProcessedText  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
# 1  cegah mata rantai covidmari kita dirumah saja ...
# 2  aku mohon yaallah semoga wabah covid menghilan...
# 3  pemprov papua naikkan status jadi tanggap daru...
# 4            covid belum nyampe prigen mbak hmm hoax
#
#                                               step01  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
# 1  cegah mata rantai covidmari kita dirumah saja ...
# 2  aku mohon yaallah semoga wabah covid menghilan...
# ...

# %%
df_new.iloc[0].tokens
# Out:
# ['emang',
#  'lemes',
#  'bgt',
#  'ya',
#  'mulut',
#  'lu',
#  'gue',
#  'yg',
#  'mau',
#  'belibeli',
#  'obat',
#  'aja',
#  'mikirr',
#  'drmn',
#  'bisa',
#  'beli',
#  'obat',
#  'kalo',
#  'ga',
#  'kerja']

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['memang',
#  'lemes',
#  'banget',
#  'iya',
#  'mulut',
#  'kamu',
#  'saya',
#  'yang',
#  'mau',
#  'belibeli',
#  'obat',
#  'saja',
#  'mikirr',
#  'drmn',
#  'bisa',
#  'beli',
#  'obat',
#  'kalau',
#  'tidak',
#  'kerja']

# %% [markdown]
# ## Stopword - Menggunakan Modul NLTK

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopword = nltk.corpus.stopwords.words('indonesian')

def remove_stopwords(text):
  text = [word for word in text if word not in stopword]
  return text

df_new['Stop_removal'] = df_new['tokens_perbaikan'].apply(lambda x: remove_stopwords(x))
df_new
# Out:
#                                                  Tweet  Sentimen  \
# 0    emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1    Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2    aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3    Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4              Covid belum nyampe prigen mbak hmm hoax       0.0
# ..                                                 ...       ...
# 900  Seluruh negara di dunia mengalami masa sulit k...       1.0
# 901  Setelah covid dan skripsi disaster selesai, ma...       1.0
# 902  Malam ini!! Projek "BENDA BOLEH BINCANG" 9 mal...       0.0
# 903                Pontang - panting di koyak covid 19      -1.0
# 904  Masalahnya sekarang isu jangkitan covid. Alaaa...      -1.0
#
#                                          ProcessedText  \
# 0    emang lemes bgt ya mulut lu gue yg mau belibel...
# 1    cegah mata rantai covidmari kita dirumah saja ...
# ...

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['memang',
#  'lemes',
#  'banget',
#  'iya',
#  'mulut',
#  'kamu',
#  'saya',
#  'yang',
#  'mau',
#  'belibeli',
#  'obat',
#  'saja',
#  'mikirr',
#  'drmn',
#  'bisa',
#  'beli',
#  'obat',
#  'kalau',
#  'tidak',
#  'kerja']

# %%
df_new.iloc[0].Stop_removal
# Out:
# ['lemes',
#  'banget',
#  'iya',
#  'mulut',
#  'belibeli',
#  'obat',
#  'mikirr',
#  'drmn',
#  'beli',
#  'obat',
#  'kerja']

# %%
i=0
final_string_tokens = []
for text in df_new['Stop_removal'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head()
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
#
#                                        ProcessedText  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
# 1  cegah mata rantai covidmari kita dirumah saja ...
# 2  aku mohon yaallah semoga wabah covid menghilan...
# 3  pemprov papua naikkan status jadi tanggap daru...
# 4            covid belum nyampe prigen mbak hmm hoax
#
#                                               step01  \
# 0  emang lemes bgt ya mulut lu gue yg mau belibel...
# 1  cegah mata rantai covidmari kita dirumah saja ...
# 2  aku mohon yaallah semoga wabah covid menghilan...
# ...

# %% [markdown]
# ## Stemming - Menggunakan Sastrawi

# %%
pip install Sastrawi
# Out:
# ...
#   Using cached Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Using cached Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df = pd.DataFrame({'ProcessedText': ["memperbaiki permasalahan yang terjadi", 
                                     "pemerintah sedang membangun jalan baru"]})

df['StemmedText'] = df['ProcessedText'].apply(lambda x: stemmer.stem(x))

df
# Out:
#                             ProcessedText                        StemmedText
# 0   memperbaiki permasalahan yang terjadi             baik masalah yang jadi
# 1  pemerintah sedang membangun jalan baru  perintah sedang bangun jalan baru

# %%
df['ProcessedText'] = df['ProcessedText'].astype(str)
df = df[df['ProcessedText'].str.strip() != ""]

# %%
batch_size = 1000
for i in range(0, len(df), batch_size):
    df.loc[i:i+batch_size-1, 'StemmedText'] = df.loc[i:i+batch_size-1, 'ProcessedText'].apply(lambda x: stemmer.stem(x))

# %%
final_string = df_new["step02"].astype(str).apply(lambda x: stemmer.stem(x))

# Simpan hasil ke kolom baru
df_new["step03_stemmed"] = final_string

# Cek hasil
df_new[["step02", "step03_stemmed"]].head()
# Out:
#                                               step02  \
# 0  lemes banget iya mulut belibeli obat mikirr dr...
# 1         cegah mata rantai covidmari dirumah minggu
# 2  mohon yaallah semoga wabah covid menghilang ra...
# 3  pemprov papua naikkan status tanggap darurat c...
# 4               covid nyampe prigen mbak aduh bohong
#
#                                       step03_stemmed
# 0  lemes banget iya mulut bibel obat mikirr drmn ...
# 1           cegah mata rantai covidmari rumah minggu
# 2     mohon yaallah moga wabah covid hilang ramadhan
# 3  pemprov papua naik status tanggap darurat covi...
# 4               covid nyampe prigen mbak aduh bohong

# %%
df_new["ProcessedText"] = final_string

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
# 5  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 6  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 7  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 8  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 9  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
#
#                                        ProcessedText  \
# 0  lemes banget iya mulut bibel obat mikirr drmn ...
# 1           cegah mata rantai covidmari rumah minggu
# 2     mohon yaallah moga wabah covid hilang ramadhan
# 3  pemprov papua naik status tanggap darurat covi...
# ...

# %% [markdown]
# ## simpan hasil preprocessing

# %%
df_new.to_csv('clean_dataset_part01.csv',sep=";")

# %% [markdown]
# # Penataan Data

# %% [markdown]
# ## pembagian fitur dan label

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_part01.csv',sep=";")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        903 non-null    int64
#  1   Tweet             903 non-null    object
#  2   Sentimen          903 non-null    float64
#  3   ProcessedText     903 non-null    object
#  4   step01            903 non-null    object
#  5   tokens            903 non-null    object
#  6   tokens_perbaikan  903 non-null    object
#  7   Stop_removal      903 non-null    object
#  8   step02            903 non-null    object
#  9   step03_stemmed    903 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 70.7+ KB

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset_feature.head(10)
# Out:
# 0    lemes banget iya mulut bibel obat mikirr drmn ...
# 1             cegah mata rantai covidmari rumah minggu
# 2       mohon yaallah moga wabah covid hilang ramadhan
# 3    pemprov papua naik status tanggap darurat covi...
# 4                 covid nyampe prigen mbak aduh bohong
# 5    nyuruh orang pintar togog kerumun orang nulari...
# 6                pikir mnde plk nk setelkn lepas covid
# 7    selamat pagi jumat jumat empat pandemi covid m...
# 8    hikmah musibah covid moga jabat perintah sadar...
# 9    cegah covid serta jajar polsek ranji aksi pedu...
# Name: ProcessedText, dtype: object

# %%
dataset_label = dataset['Sentimen']

# %%
dataset_label.head(10)
# Out:
# 0   -1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# 5   -1.0
# 6    0.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: Sentimen, dtype: float64

# %% [markdown]
# ## distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10468\1470841120.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')

# %%
dataset_label.value_counts()
# Out:
# Sentimen
#  1.0    441
#  0.0    266
# -1.0    196
# Name: count, dtype: int64

# %% [markdown]
# # Ekstraksi Fitur dan Machine Learning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_label, test_label = train_test_split(dataset_feature, dataset_label, test_size = 0.3, random_state=42)

# %%
test_x
# Out:
# 70     tips ilmuwan tingkat kebal tubuh mari lawan co...
# 457    cegah covid serta jajar polsek ranji aksi pedu...
# 218    warga kabupaten lampung utara nyata positif pa...
# 250    mimpi malam psbb tahan batal covid data tambah...
# 39     mungkinyukkkkita putus mata rantai semangat co...
#                              ...
# 864                  orang bahaya covid lurus belokpergi
# 638    halo gerak lawan covid ayo juang informasi ind...
# 352    personil polsek karanglewas laksana patroli ma...
# 465    amal langkahlangkah cegah tular covid amal hid...
# 640           wakakakkaka puter cahaya tolong time covid
# Name: ProcessedText, Length: 271, dtype: object

# %% [markdown]
# ## load TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Tfidf_Vectorizer = TfidfVectorizer()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.pipeline import Pipeline
classifier_nb = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

# %%
parameters_nb = {
    'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
    'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100)
}

# %%
classifier_nb = GridSearchCV(classifier_nb, parameters_nb, cv = 3, n_jobs=-1)

# %%
classifier_nb.fit(train_x, train_label.ravel())
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10468\4039834798.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   classifier_nb.fit(train_x, train_label.ravel())
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100),
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3),
#                                                 (1, 4)]})

# %%
y_pred_nb_train = classifier_nb.predict(train_x)
accuracy_nb_train = accuracy_score(train_label, y_pred_nb_train)
print("Accuracy Training set: ", accuracy_nb_train)

y_pred_nb_test = classifier_nb.predict(test_x)
accuracy_nb_test = accuracy_score(test_label, y_pred_nb_test)
print("Accuracy Test set: ", accuracy_nb_test)
# Out:
# Accuracy Training set:  0.9794303797468354
# Accuracy Test set:  0.5977859778597786

# %%
recall_nb_train = recall_score(train_label, y_pred_nb_train, average='weighted')
print("Recall Training set: ", recall_nb_train)

recall_nb_test = recall_score(test_label, y_pred_nb_test, average='weighted')
print("Recall Test set: ", recall_nb_test)
# Out:
# Recall Training set:  0.9794303797468354
# Recall Test set:  0.5977859778597786

# %%
precision_nb_train = precision_score(train_label, y_pred_nb_train, average='weighted')
print("Precision Training set: ", precision_nb_train)

precision_nb_test = precision_score(test_label, y_pred_nb_test, average='weighted')
print("Precision Test set: ", precision_nb_test)
# Out:
# Precision Training set:  0.9796640055788738
# Precision Test set:  0.5830611371706063

# %%
f1_nb_train = f1_score(train_label, y_pred_nb_train, average='weighted')
print("F1 Training set: ", f1_nb_train)

f1_nb_test = f1_score(test_label, y_pred_nb_test, average='weighted')
print("F1 Test set: ", f1_nb_test)
# Out:
# F1 Training set:  0.9794493074255752
# F1 Test set:  0.5857918852256725

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test_label, y_pred_nb_test), annot=True, cmap = 'viridis', fmt='.0f')
plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
plt.show()

# %%
classifier_nb.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('model', MultinomialNB(alpha=0.1))])

# %%
for param_name in sorted(parameters_nb.keys()):
    print("%s: %r" % (param_name, classifier_nb.best_params_[param_name]))
# Out:
# model__alpha: 0.1
# tfidf__ngram_range: (1, 1)

# %% [markdown]
# # Visualisasi

# %%
models = [        
          ('Naive Bayes Multinomial', accuracy_nb_train, accuracy_nb_test),
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'Training Accuracy', 'Test Accuracy'])
predict
# Out:
#                      Model  Training Accuracy  Test Accuracy
# 0  Naive Bayes Multinomial            0.97943       0.597786

# %%
models_comparison = [                        
                        ('Naive Bayes Multinomial', accuracy_nb_test, recall_nb_test, precision_nb_test, f1_nb_test)                      
                    ]

# %%
comparison = pd.DataFrame(data = models_comparison, columns=['Model', 'Accuracy', 'Recall', 'Precision', 'F1 Weighted'])
comparison
# Out:
#                      Model  Accuracy    Recall  Precision  F1 Weighted
# 0  Naive Bayes Multinomial  0.597786  0.597786   0.583061     0.585792

# %%
import numpy as np

f, axes = plt.subplots(2,1, figsize=(14,10))

predict.sort_values(by=['Training Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Training Accuracy', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))

predict.sort_values(by=['Test Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Test Accuracy', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))

plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10468\2750282873.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10468\2750282873.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])

# %% [markdown]
# # simpan kedalam joblib

# %%
import joblib

# %%
# save the model to disk
joblib.dump(classifier_nb.best_estimator_, 'classifier_nb.best_estimator_.sav', compress=1)
# Out:
# ['classifier_nb.best_estimator_.sav']
